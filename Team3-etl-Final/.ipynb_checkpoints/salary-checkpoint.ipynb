# %%
from splinter import Browser
from bs4 import BeautifulSoup
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
import pandas as pd
import requests
import pymongo
import time
import numpy as np

# %% [markdown]
# ## Source: https://www.calu.edu

# %%
url = 'https://www.calu.edu/academics/undergraduate/bachelors/data-science/what-can-you-do-with-a-statistics-and-data-science-degree.aspx'
#browser.visit(url)

# Retrieve page with the requests module
response = requests.get(url)

# Create BeautifulSoup object; parse with 'html.parser'
title_soup = BeautifulSoup(response.text, 'html.parser')

print(title_soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang=""> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9" lang=""> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/>
#   <title>
#    What Can You Do With A Statistics And Data Science Degree
#   </title>
#   <link href="https://www.calu.edu/academics/undergraduate/bachelors/data-science/what-can-you-do-with-a-statistics-and-data-science-degree.aspx" rel="canonical"/>
#   <meta content="What can you do with a Statistics and Data Science degree? Learn about career options, as well as details about Cal U’s affordable bachelor degree program." name="Description"/>
#   <meta content="what can you do with a statistics and data science degree, statistics degree, data science degree, sas certificate, cal u, california university of pennsylvania" name="Keywords"/>
#   <!-- Core CSS -->
#   <link href="/_resources/css/all.css?v=2.1" rel="stylesheet"/>
#   <!-- Favicons -->
#   <link href="/_resources/favicon/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/_resources/favicon/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/_resources/favicon/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/_resources/favicon/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/_resources/favicon/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/_resources/favicon/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/_resources/favicon/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/_resources/favicon/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/_resources/favicon/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="California University of Pennsylvania" name="apple-mobile-web-app-title"/>
#   <link href="/_resources/favicon/coast-228x228.png" rel="icon" sizes="228x228" type="image/png"/>
#   <link href="/_resources/favicon/manifest.json" rel="manifest"/>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="California University of Pennsylvania" name="application-name"/>
#   <link href="/_resources/favicon/yandex-browser-manifest.json" rel="yandex-tableau-widget"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="favicon/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="favicon/browserconfig.xml" name="msapplication-config"/>
#   <link href="/_resources/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/_resources/favicon/android-chrome-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/_resources/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/_resources/favicon/favicon.ico" rel="shortcut icon"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/webfont/1.6.26/webfont.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    WebFont.load({  google: {    families: ["PT Serif:400,400italic,700,700italic","Roboto:300,300italic,regular,italic,500,500italic,700,700italic,900,900italic"]  }});
#   </script>
#   <script src="https://use.typekit.net/pww6eik.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    try{Typekit.load();}catch(e){}
#   </script>
#   <link href="/_resources/css/ou-styles.css?v=1.2" rel="stylesheet"/>
#   <!-- Open Graph Protocol Meta -->
#   <meta content="California University of Pennsylvania" property="og:site_name"/>
#   <meta content="What Can You Do With A Statistics And Data Science Degree" property="og:title"/>
#   <meta content="https://www.calu.edu/academics/undergraduate/bachelors/data-science/what-can-you-do-with-a-statistics-and-data-science-degree.aspx" property="og:url"/>
#   <meta content="What Can You Do with a Statistics and Data Science Degree" property="og:image"/>
#   <meta content="https://www.calu.edu/academics/undergraduate/bachelors/data-science/_files/data-science6.jpg" property="og:image:url"/>
#   <meta property="og:image:width"/>
#   <meta property="og:image:height"/>
#   <meta content=".jpg" property="og:image:type"/>
#   <meta content="What can you do with a Statistics and Data Science degree? Learn about career options, as well as details about Cal U’s affordable bachelor degree program." property="og:description"/>
#   <!-- END Open Graph Protocol Meta -->
#   <script type="text/javascript">
#    var OUC = OUC || {};
# 				OUC.dirname = "/academics/undergraduate/bachelors/data-science/";
# 				OUC.filename = "what-can-you-do-with-a-statistics-and-data-science-degree.aspx";
# 				OUC.path = OUC.dirname + OUC.filename;
#
# 				var page_url="https://www.calu.edu/academics/undergraduate/bachelors/data-science/what-can-you-do-with-a-statistics-and-data-science-degree.aspx";
#   </script>
#   <!-- Twitter Deep Linking -->
#   <meta content="summary" name="twitter:card"/>
#   <meta content="What Can You Do With A Statistics And Data Science Degree" name="twitter:title"/>
#   <meta content="What can you do with a Statistics and Data Science degree? Learn about career options, as well as details about Cal U’s affordable bachelor degree program." name="twitter:description"/>
#   <meta content="@CalUofPA" name="twitter:site"/>
#   <!-- Banner Alert -->
#   <script defer="" src="https://s3.amazonaws.com/widgets.omnilert.net/368f164ecc2818530f15a81f129e6c87-8910">
#   </script>
#   <!-- End Banner Alert -->
#   <!-- Google Tag Manager -->
#   <script defer="">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-KP23VVZ');
#   </script>
#   <!-- End Google Tag Manager -->
#   <!-- Global site tag (gtag.js) - Google Ads: 754533178 -->
#   <script defer="" src="https://www.googletagmanager.com/gtag/js?id=AW-754533178">
#   </script>
#   <script defer="" src="https://tag.simpli.fi/sifitag/4d063470-b60e-0137-64a0-067f653fa718">
#   </script>
#   <script defer="" src="https://tag.simpli.fi/sifitag/51016130-b60e-0137-eb11-06a9ed4ca31b">
#   </script>
#   <script defer="async" src="https://adm.calu.edu/ping">
#   </script>
#  </head>
#  <body>
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KP23VVZ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <!--[if lt IE 8]>
#             <p class="browserupgrade">You are using an <strong>outdated</strong> browser. Please upgrade your browser to improve your experience.</p>
#         <![endif]-->
#   <input class="calu-hidden" id="trigger-navigation" type="checkbox" value="Show navigation menu"/>
#   <div class="b-main-header-wrapper">
#    <header class="b-main-header" role="banner">
#     <a class="b-main-header__logo-link" href="/">
#      <img alt="California University of Pennsylvania logo" class="b-main-header__logo-image" src="/_resources/images/calu-logo-compressor.svg"/>
#     </a>
#     <label class="b-menu-trigger b-menu-trigger--header" for="trigger-navigation">
#      <svg height="25" id="burgericon-main" width="30" xmlns="http://www.w3.org/2000/svg">
#       <g class="icon">
#        <rect class="b-menu-trigger__bar b-menu-trigger--first-bar" fill="#d8d8d8" height="3" rx="0" ry="0" width="30" x="0" y="0">
#        </rect>
#        <rect class="b-menu-trigger__bar b-menu-trigger--second-bar" fill="#d8d8d8" height="3" rx="0" ry="0" width="30" x="0" y="10">
#        </rect>
#        <rect class="b-menu-trigger__bar b-menu-trigger--third-bar" fill="#d8d8d8" height="3" rx="0" ry="0" width="30" x="0" y="20">
#        </rect>
#       </g>
#      </svg>
#      <span class="calu-hidden">
#       Show Menu
#      </span>
#     </label>
#     <div class="b-main-header-wrapper--mobile-hide b-main-header__tools">
#      <div class="b-select-menu">
#       <label class="b-select-menu__trigger b-select-menu--header" for="trigger-audience">
#        Information for...
#        <svg class="b-select-menu__icon" height="11px" width="16px" xmlns="http://www.w3.org/2000/svg">
#         <g fill="none" fill-rule="evenodd" stroke="none" stroke-width="1">
#          <g fill="#E03127" transform="translate(-914.000000, -699.000000)">
#           <polygon points="921.615376 699 929.230751 710 914 710" transform="translate(921.615376, 704.500000) rotate(180.000000) translate(-921.615376, -704.500000) ">
#           </polygon>
#          </g>
#         </g>
#        </svg>
#       </label>
#       <input class="calu-hidden" id="trigger-audience" type="checkbox" value="Show Information For Menu"/>
#       <div class="b-select-menu__menu-wrapper calu-hidden">
#        <ul class="b-list-reset b-select-menu__menu">
#         <li class="b-list-reset__list-item">
#          <a class="b-select-menu__item" href="/inside/student-resources/index.aspx">
#           Current Students
#          </a>
#         </li>
#         <li class="b-list-reset__list-item">
#          <a class="b-select-menu__item" href="/inside/faculty-staff/">
#           Faculty/Staff
#          </a>
#         </li>
#         <li class="b-list-reset__list-item">
#          <a class="b-select-menu__item" href="/alumni/index.aspx">
#           Alumni
#          </a>
#         </li>
#         <li class="b-list-reset__list-item">
#          <a class="b-select-menu__item" href="/parents/">
#           Parents
#          </a>
#         </li>
#         <li class="b-list-reset__list-item">
#          <a class="b-select-menu__item" href="/community/">
#           Community
#          </a>
#         </li>
#         <span class="b-select-menu__heading">
#          Future Students
#         </span>
#         <ul class="b-list-reset">
#          <li class="b-list-reset__list-item">
#           <a class="b-select-menu__item" href="/undergraduate/">
#            Undergraduate
#           </a>
#          </li>
#          <li class="b-list-reset__list-item">
#           <a class="b-select-menu__item" href="/graduate/">
#            Graduate
#           </a>
#          </li>
#          <li class="b-list-reset__list-item">
#           <a class="b-select-menu__item" href="/international-students/">
#            International
#           </a>
#          </li>
#          <li class="b-list-reset__list-item">
#           <a class="b-select-menu__item" href="/online/">
#            Online
#           </a>
#          </li>
#          <li class="b-list-reset__list-item">
#           <a class="b-select-menu__item" href="/military-veteran/">
#            Military &amp; Veteran
#           </a>
#          </li>
#          <li class="b-list-reset__list-item">
#           <a class="b-select-menu__item" href="/continuing-education/">
#            Continuing Education
#           </a>
#          </li>
#         </ul>
#        </ul>
#       </div>
#      </div>
#      <form action="https://www.calu.edu/search-results.aspx" class="b-search" id="cse-search-box-main" role="search">
#       <input name="cx" type="hidden" value="009671096780567527873:5dh40bbbyoq"/>
#       <label class="calu-hidden" for="calu-search">
#        Search...
#       </label>
#       <input accesskey="4" class="b-search__input" id="calu-search" name="q" type="search"/>
#       <input name="cof" type="hidden" value="FORID:10"/>
#      </form>
#      <script src="https://www.google.com/coop/cse/brand?form=cse-search-box&amp;lang=en" type="text/javascript">
#      </script>
#      <a class="b-main-header__cta" href="/admissions/apply/index.aspx">
#       Apply
#       <svg class="b-main-header--icon" height="14px" viewbox="0 0 14 14" width="14px" xmlns="http://www.w3.org/2000/svg">
#        <g fill="#FFFFFF" transform="translate(-798.000000, -31.000000)">
#         <path d="M798.549164,43.9737426 C798.689338,44.1139165 798.960389,44.2151056 799.136635,44.2196038 L809.133251,44.5226999 C809.59349,44.5304111 809.987207,44.1908579 810.013584,43.6896249 C810.037189,43.241514 809.629074,42.821635 809.18047,42.8092541 L801.162387,42.5724322 L811.272115,32.4626954 C811.606733,32.1280688 811.606725,31.5856233 811.272111,31.2509967 C810.937497,30.9163701 810.394996,30.9163273 810.060391,31.250911 L799.950646,41.3606907 L799.713824,33.3425949 C799.7014,32.8940556 799.282164,32.5057072 798.833496,32.50952 C798.359809,32.513804 797.985684,32.9294847 798.000421,33.3898479 L798.303517,43.3864432 C798.299233,43.6685474 798.40929,43.8290705 798.549164,43.9737426 L798.549164,43.9737426 Z" transform="translate(804.761538, 37.761414) scale(-1, -1) translate(-804.761538, -37.761414) ">
#         </path>
#        </g>
#       </svg>
#      </a>
#     </div>
#    </header>
#    <nav class="b-navigation b-main-header-wrapper--mobile-hide" role="navigation">
#     <ul class="b-list-reset b-column-to-row">
#      <li class="b-navigation__nav-item b-list-reset__list-item b-column-to-row__item">
#       <a class="b-navigation__nav-link" href="/academics/">
#        Academics
#       </a>
#      </li>
#      <li class="b-navigation__nav-item b-list-reset__list-item b-column-to-row__item">
#       <a class="b-navigation__nav-link" href="/admissions/">
#        Admissions
#       </a>
#      </li>
#      <li class="b-navigation__nav-item b-list-reset__list-item b-column-to-row__item">
#       <a class="b-navigation__nav-link" href="/calu-difference/">
#        Our Difference
#       </a>
#      </li>
#      <li class="b-navigation__nav-item b-list-reset__list-item b-column-to-row__item">
#       <a class="b-navigation__nav-link" href="/student-life/">
#        Student Life
#       </a>
#      </li>
#      <li class="b-navigation__nav-item b-list-reset__list-item b-column-to-row__item">
#       <a class="b-navigation__nav-link" href="/costs-aid/">
#        Costs and Aid
#       </a>
#      </li>
#      <li class="b-navigation__nav-item b-list-reset__list-item b-column-to-row__item">
#       <a class="b-navigation__nav-link" href="/inside/student-resources/index.aspx">
#        Current Students
#       </a>
#      </li>
#      <li class="b-navigation__nav-item b-list-reset__list-item b-column-to-row__item">
#       <a class="b-navigation__nav-link" href="http://www.calvulcans.com/">
#        Athletics
#       </a>
#      </li>
#     </ul>
#    </nav>
#   </div>
#   <nav class="b-breadcrumbs">
#    <a class="b-breadcrumbs__link b-breadcrumbs__link--home" href="/">
#     Home
#    </a>
#    <a class="b-breadcrumbs__link" href="/academics/">
#     Academics
#    </a>
#    <a class="b-breadcrumbs__link" href="/academics/undergraduate/">
#     Undergraduate Programs
#    </a>
#    <a class="b-breadcrumbs__link" href="/academics/undergraduate/bachelors/">
#     Bachelor's Degree Programs
#    </a>
#    <a class="b-breadcrumbs__link" href="/academics/undergraduate/bachelors/data-science/">
#     Statistics and Data Science
#    </a>
#    <a class="b-breadcrumbs__link" href="/academics/undergraduate/bachelors/data-science/">
#     What Can You Do with a Statistics and Data Science Degree
#    </a>
#   </nav>
#   <input class="calu-hidden" id="trigger-section-navigation" type="checkbox" value="Show navigation menu"/>
#   <div class="b-band">
#    <div class="b-band__inner">
#     <div class="b-section-nav__trigger">
#      <label class="b-menu-trigger" for="trigger-section-navigation">
#       <svg height="16" id="burgericon-section" width="20" xmlns="http://www.w3.org/2000/svg">
#        <g class="icon">
#         <rect class="b-menu-trigger__bar b-menu-trigger--first-bar" fill="#d8d8d8" height="2" rx="0" ry="0" width="20" x="0" y="0">
#         </rect>
#         <rect class="b-menu-trigger__bar b-menu-trigger--second-bar" fill="#d8d8d8" height="2" rx="0" ry="0" width="20" x="0" y="7">
#         </rect>
#         <rect class="b-menu-trigger__bar b-menu-trigger--third-bar" fill="#d8d8d8" height="2" rx="0" ry="0" width="20" x="0" y="14">
#         </rect>
#        </g>
#       </svg>
#       <span class="b-section-nav__label">
#        Section Navigation
#       </span>
#      </label>
#     </div>
#     <div class="b-row b-row--is-bp2">
#      <div class="b-row__column b-row__column--is-one-quarter-bp2">
#       <nav class="b-section-nav">
#        <ul class="b-section-nav__list">
#         <li class="b-section-nav__item">
#          <ul class="b-section-nav__list">
#           <li class="b-section-nav__item">
#            <a href="/academics/undergraduate/bachelors/data-science/index.aspx">
#             Statistics and Data Science
#            </a>
#           </li>
#           <li class="b-section-nav__item">
#            <a href="/academics/undergraduate/bachelors/data-science/sas-certificates-bachelor-master-degree.aspx">
#             The Cal U Advantage For Data Science: SAS Certificates, Bachelor, and Master Programs
#            </a>
#           </li>
#           <li class="b-section-nav__item">
#            <a href="/academics/undergraduate/bachelors/data-science/what-is-a-statistics-data-science-degree.aspx">
#             What Is a Statistics and Data Science Degree
#            </a>
#           </li>
#           <li class="b-section-nav__item">
#            <a class="b-section-nav__item--current" href="/academics/undergraduate/bachelors/data-science/what-can-you-do-with-a-statistics-and-data-science-degree.aspx">
#             What Can You Do with a Statistics and Data Science Degree
#            </a>
#           </li>
#           <li class="b-section-nav__item">
#            <a href="/academics/undergraduate/bachelors/data-science/big-data.aspx">
#             Big Data
#            </a>
#           </li>
#           <li class="b-section-nav__item">
#            <a href="/academics/undergraduate/bachelors/data-science/jobs-career-salaries.aspx">
#             Data Science: One Of The Fastest Growing Occupations
#            </a>
#           </li>
#           <li class="b-section-nav__item">
#            <a href="/academics/undergraduate/bachelors/data-science/benefits-of-an-sas-certificate.aspx">
#             Benefits Of An SAS Certificate
#            </a>
#           </li>
#           <li class="b-section-nav__item">
#            <a href="/academics/undergraduate/bachelors/data-science/benefits-of-an-sas-graduate-certificate.aspx">
#             Benefits Of An SAS Graduate Certificate
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#       </nav>
#      </div>
#      <section id="main-content">
#       <h1 class="b-page-header">
#        <strong>
#         what can you do with a statistics and data science degree?
#        </strong>
#       </h1>
#       <p>
#        It may come as no surprise that global companies like Facebook, Netflix, Amazon and
#                   Twitter heavily rely on increasing amounts of data to produce tailored content and
#                   personalized advertising. But did you know that this
#        <a href="/academics/undergraduate/bachelors/data-science/big-data.aspx">
#         “data deluge”
#        </a>
#        is currently transforming the day-to-day operations of nearly
#        <strong>
#         every business and industry
#        </strong>
#        ?
#       </p>
#       <p>
#        Along with the immense amount of big data being generated today comes an
#        <a href="/academics/undergraduate/bachelors/data-science/jobs-career-salaries.aspx">
#         increasing need for trained data scientists
#        </a>
#        and statisticians who can gather, analyze and interpret that data. In 2020 alone,
#                   there is expected to be
#        <strong>
#         nearly 3 million
#        </strong>
#        <strong>
#         new job
#        </strong>
#        postings for professionals with data science and analytic skills.
#       </p>
#       <p>
#        A
#        <a href="/academics/undergraduate/bachelors/data-science/index.aspx">
#         data science degree
#        </a>
#        from California University of Pennsylvania will enable you to enter the booming career
#                   field of data science with the hands-on experience and training needed by today’s
#                   most innovative companies.
#       </p>
#       <p>
#        You’ll graduate
#        <a href="/academics/undergraduate/bachelors/data-science/what-is-a-statistics-data-science-degree.aspx">
#         with in-demand software and big data skills
#        </a>
#        , and will be ready to join the ranks of top data scientists, data analysts and statisticians
#                   across industries. You’ll also be prepared for certification as an
#        <strong>
#         SAS Certified Big Data Professional
#        </strong>
#        — an industry recognized credential from a global leader in analytics software that
#                   will help you stand out in your job applications.
#       </p>
#       <p>
#        <a href="/academics/undergraduate/bachelors/data-science/sas-certificates-bachelor-master-degree.aspx">
#         Learn more about the Cal U advantage for data science.
#        </a>
#       </p>
#       <h2>
#        <strong>
#         Primary job paths for data science and statistics majors
#        </strong>
#       </h2>
#       <p>
#        Most graduates of statistics and data science degree programs go on to careers in
#                   the four job categories:
#       </p>
#       <ul>
#        <li>
#         <strong>
#          Data Analyst:
#         </strong>
#         A career as a data analyst consists of transforming data into information that can
#                      be easily read, and which offers actionable insight into business decisions.
#        </li>
#        <li>
#         <strong>
#          Data Architect:
#         </strong>
#         The job of data architect is to help companies create database structures based on
#                      their particular data storage and retrieval needs. Data architects also use data software
#                      and computer programming skills to monitoring and troubleshoot database issues.
#        </li>
#        <li>
#         <strong>
#          Data Scientist:
#         </strong>
#         A career as a data scientist involved turning data into value. Job responsibilities
#                      include retrieving and analyzing data to improve business performance, and building
#                      AI tools that can automate tasks.
#        </li>
#        <li>
#         <strong>
#          Information Officer:
#         </strong>
#         The job of an information officer is to manage, maintain and organize databases and
#                      digital resources. Information officers also use their data science expertise to ensure
#                      data is both highly protected and easily accessible.
#        </li>
#       </ul>
#       <p>
#       </p>
#       <p>
#        Read on to learn more about what you can do with a statistics and data science degree.
#       </p>
#       <div class="b-band b-band__cta-band admissionsbuttons">
#        <a class="b-button b-button--red b-button--maxer" href="/academics/undergraduate/bachelors/data-science/">
#         Programs
#        </a>
#        <a class="b-button b-button--red b-button--maxer" href="https://adm.calu.edu/register/calurfi?sys:field:student_type=c8266597-c759-492d-9500-532c69a25390">
#         Request Info
#        </a>
#        <a class="b-button b-button--red b-button--maxer" href="https://www.calu.edu/admissions/apply/">
#         Apply Now
#        </a>
#       </div>
#       <h2>
#        <strong>
#         Salaries and job titles data science and statistics degree holders
#        </strong>
#       </h2>
#       <p>
#        Though the above jobs cover the main career areas that data science and statistics
#                   majors pursue, the data science job market is full of variety and nuance. To help
#                   you get a picture of the broad range of what can you do with a statistics and data
#                   science degree—and the
#        <strong>
#         impressive salaries
#        </strong>
#        you can expect in various positions—here is a sample list of data science job titles
#                   you can pursue with Cal U data science degree.
#        <span>
#        </span>
#        Which job is right for you?
#       </p>
#       <ul>
#        <li>
#         <strong>
#          Data scientist:
#         </strong>
#         According to Glassdoor, the average salary for data scientists in the US is
#         <strong>
#          $120,931
#         </strong>
#         . If you work for a global mega company, like Facebook, you can expect to be earning
#                      well over $200k.
#        </li>
#        <li>
#         <strong>
#          Business intelligence analyst:
#         </strong>
#         According to Glassdoor, business intelligence analysts earn an average of
#         <strong>
#          $79,613
#         </strong>
#         per year
#         <strong>
#          .
#         </strong>
#        </li>
#        <li>
#         <strong>
#          Chief information officer:
#         </strong>
#         According to Indeed, a job as a Chief information officer can earn you an average
#                      of
#         <strong>
#          $121,652
#         </strong>
#         per year.
#        </li>
#        <li>
#         <strong>
#          Data warehouse analyst:
#         </strong>
#         A data analyst working in a warehouse setting earns and average of
#         <strong>
#          $71,328
#         </strong>
#         per year, according to Glassdoor
#         <strong>
#          .
#         </strong>
#        </li>
#        <li>
#         <strong>
#          Data Visualization Developer:
#         </strong>
#         In the exciting career of data visualization developer you can expect to earn an average
#                      of
#         <strong>
#          $118,500
#         </strong>
#         per year, according to
#         <a href="https://www.ziprecruiter.com/Salaries/Data-Visualization-Developer-Salary" rel="nofollow">
#          Zip Recruiter
#         </a>
#         .
#        </li>
#        <li>
#         <strong>
#          Business System Analyst:
#         </strong>
#         This in-demand data science job has an average salary of
#         <strong>
#          $74,668
#         </strong>
#         year according to Glassdoor.
#        </li>
#        <li>
#         <strong>
#          Data mining analyst:
#         </strong>
#         This essential data analyst job has and average salary of
#         <strong>
#          $65,470
#         </strong>
#         , according to Glassdoor.
#        </li>
#        <li>
#         <strong>
#          Big Data Solutions Architect:
#         </strong>
#         Glassdoor reports the national average salary for big data solutions architects as
#         <strong>
#          $116,171
#         </strong>
#         per year.
#        </li>
#        <li>
#         <strong>
#          Database manager:
#          <span>
#          </span>
#         </strong>
#         Your statistics and data science degree could earn you an average of
#         <strong>
#          $76,088
#         </strong>
#         per year in the role of database manager, according to Glassdoor.
#        </li>
#        <li>
#         <strong>
#          Data modeler:
#         </strong>
#         If you like building conceptual and physical models of data, this data science career
#                      can earn you
#         <strong>
#          $78,601
#         </strong>
#         per year, according to Glassdoor.
#        </li>
#        <li>
#         <strong>
#          Database developer:
#         </strong>
#         A well-paid career that is needed in nearly all industries, the role of data base
#                      developer brings in an average of
#         <strong>
#          $86,090
#         </strong>
#         per year, according to Glassdoor.
#        </li>
#        <li>
#         <strong>
#          Database administrator:
#         </strong>
#         Your Cal U data science degree can land you a job as a database developer, which according
#                      to Glassdoor has an average salary of
#         <strong>
#          $77,428
#         </strong>
#         per year.
#        </li>
#        <li>
#         <strong>
#          Data strategist:
#         </strong>
#         PayScale reports that the average salary for career data strategists is
#         <strong>
#          $57, 946
#         </strong>
#         per year.
#        </li>
#        <li>
#         <strong>
#          Business data analyst:
#         </strong>
#         No matter which industry you work in, the career of business data analyst is a solid
#                      bet with an average salary of
#         <strong>
#          $67,610
#         </strong>
#         per year, according to Glassdoor.
#        </li>
#        <li>
#         <strong>
#          Data engineer:
#         </strong>
#         One of the higher-paying positions you can pursue as a data science and statistics
#                      major is data engineer. According to Glassdoor in this job you can expect to earn
#                      an average of
#         <strong>
#          $137,776
#         </strong>
#         per year.
#        </li>
#        <li>
#         <strong>
#          Machine learning engineer:
#         </strong>
#         The dynamic career of machine learning engineer has an average salary of
#         <strong>
#          $120,931
#         </strong>
#         per year, according to Glassdoor.
#        </li>
#       </ul>
#       <p>
#        Are you ready to take on one of these fascinating—and lucrative—careers in data science.
#                   Cal U’s bachelor’s degree in statistics and data science can prepare you for job success.
#        <a href="/admissions/apply/index.aspx">
#         Apply to Cal U today
#        </a>
#        .
#       </p>
#       <div class="b-media b-media--left-bp3">
#        <div class="b-media__element">
#         <img alt="What is a data science degree?" class="" height="500" src="/academics/undergraduate/bachelors/data-science/_files/data-science2.jpg" width="1000"/>
#        </div>
#        <div class="b-media__description">
#         <h3 class="b-media__title">
#          Data Science Explained
#         </h3>
#         <p class="b-media__sub-title">
#          Cal U data science bachelor's degree
#         </p>
#         <p>
#          <span>
#           At Cal U, you’ll learn how to think like a data scientist. Discover what this mean,
#                            and the specifics of the degree program.
#          </span>
#         </p>
#         <p>
#          <a href="/academics/undergraduate/bachelors/data-science/what-is-a-statistics-data-science-degree.aspx">
#           Learn more
#          </a>
#         </p>
#        </div>
#       </div>
#       <p>
#       </p>
#       <div class="b-media b-media--left-bp3">
#        <div class="b-media__element">
#         <img alt="data science." class="" height="500" src="/academics/undergraduate/bachelors/data-science/_files/data-science5.jpg" width="1000"/>
#        </div>
#        <div class="b-media__description">
#         <h3 class="b-media__title">
#          The Data Science Boom
#         </h3>
#         <p class="b-media__sub-title">
#          Job growth for data science majors
#         </p>
#         <p>
#          <span>
#           Did you know there are more data science positions than there are professionals to
#                            fill them? Read more.
#          </span>
#         </p>
#         <p>
#          <a href="/academics/undergraduate/bachelors/data-science/jobs-career-salaries.aspx">
#           Learn more.
#          </a>
#         </p>
#        </div>
#       </div>
#       <p class="p4">
#       </p>
#       <div class="b-media b-media--left-bp3">
#        <div class="b-media__element">
#         <img alt="Data science concept." class="" height="500" src="/academics/undergraduate/bachelors/data-science/_files/data-science6.jpg" width="1000"/>
#        </div>
#        <div class="b-media__description">
#         <h3 class="b-media__title">
#          Big - Data
#         </h3>
#         <p class="b-media__sub-title">
#          The top job skill today
#         </p>
#         <p>
#          The “information glut” is a huge challenge for businesses, both small and large. Learn
#                         why big data skills are needed more than ever.
#         </p>
#         <p>
#          <a href="/academics/undergraduate/bachelors/data-science/big-data.aspx">
#           Learn more.
#          </a>
#         </p>
#        </div>
#       </div>
#       <p class="p4">
#       </p>
#       <div class="b-media b-media--left-bp3">
#        <div class="b-media__element">
#         <img alt="Data science concept." class="" height="500" src="/academics/undergraduate/bachelors/data-science/_files/data-science8.jpg" width="1000"/>
#        </div>
#        <div class="b-media__description">
#         <h3 class="b-media__title">
#          Graduate Certificate in Data Science
#         </h3>
#         <p class="b-media__sub-title">
#          Program benefits
#         </p>
#         <p>
#          <span>
#           Earn a graduate SAS certificate 100% online in as little as 10 weeks. Learn more about
#                            this career-boosting program.
#          </span>
#          <br/>
#          <span>
#          </span>
#         </p>
#         <p>
#          <a href="/academics/undergraduate/bachelors/data-science/benefits-of-an-sas-graduate-certificate.aspx">
#           Learn more.
#          </a>
#         </p>
#        </div>
#       </div>
#       <p class="p4">
#       </p>
#      </section>
#     </div>
#    </div>
#   </div>
#   <div class="b-footer-band b-footer-band--light-gray">
#    <div class="b-footer-band__flex-bar b-footer-band__flex-bar--centered">
#     <div class="b-choice" id="step1">
#      <span class="b-button b-button--gray b-button--footer">
#       I am a future
#      </span>
#      <div class="b-choice__wrapper">
#       <ul class="b-list-reset b-choice__list">
#        <li class="b-list-reset__list-item" data-path="undergraduate" data-step="1">
#         Undergraduate Student
#        </li>
#        <li class="b-list-reset__list-item" data-path="graduate" data-step="1">
#         Graduate Student
#        </li>
#        <li class="b-list-reset__list-item" data-path="international" data-step="1">
#         International Student
#        </li>
#        <li class="b-list-reset__list-item" data-path="online" data-step="1">
#         Online Student
#        </li>
#        <li class="b-list-reset__list-item" data-path="military" data-step="1">
#         Military &amp; Veteran Student
#        </li>
#        <li class="b-list-reset__list-item" data-path="continuing" data-step="1">
#         Continuing Education Student
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="b-choice" id="step2">
#      <span class="b-button b-button--gray b-button--footer">
#       Help me find
#      </span>
#      <div class="b-choice__wrapper">
#       <ul class="b-list-reset b-choice__list">
#        <li class="b-list-reset__list-item" data-path="academics" data-step="2">
#         Academics
#        </li>
#        <li class="b-list-reset__list-item" data-path="admissions" data-step="2">
#         Admissions
#        </li>
#        <li class="b-list-reset__list-item" data-path="cost-aid" data-step="2">
#         Costs &amp; Aid
#        </li>
#       </ul>
#      </div>
#     </div>
#    </div>
#   </div>
#   <footer>
#    <div class="b-footer-band b-footer-band--gray">
#     <div class="b-footer-band__flex-bar">
#      <a class="b-button b-button--red" href="/admissions/apply/index.aspx">
#       Apply
#      </a>
#      <a class="b-button b-button--red" href="/admissions/request-information.aspx">
#       Request Info
#      </a>
#      <a class="b-button b-button--red" href="/admissions/visit/index.aspx">
#       Visit
#      </a>
#      <a class="b-button b-button--red" href="/giving/index.aspx">
#       Give
#      </a>
#     </div>
#    </div>
#    <div class="b-footer-band b-footer-band--black">
#     <div class="b-footer-band__flex-bar">
#      <div class="b-footer-band__column b-footer-band__column--two">
#       <div class="b-footer-band__outposts b-footer-band__flex-bar">
#        <!-- Facebook -->
#        <a class="b-outpost-icon" href="https://www.facebook.com/CalUofPA/" title="Like us on Facebook">
#         <svg version="1.1" viewbox="0 0 110 110" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#          <g fill="none" fill-rule="evenodd">
#           <g fill="#fff" transform="translate(-60 -37)">
#            <path d="m60 91.833c0-30.284 24.55-54.833 54.83-54.833 30.29 0 54.83 24.549 54.83 54.833 0 30.287-24.54 54.837-54.83 54.837-30.28 0-54.83-24.55-54.83-54.837zm68.73 0.02l1.17-11.437h-10.26v-6.738c0-2.527 1.67-3.121 2.86-3.121h7.24v-11.112l-9.98-0.043c-11.08 0-13.59 8.297-13.59 13.594v7.408h-6.409v11.449h6.409v32.407h13.47v-32.407h9.09z" id="icon-facebook">
#            </path>
#           </g>
#          </g>
#         </svg>
#         <span class="calu-hidden">
#          Like us on Facebook
#         </span>
#        </a>
#        <!-- YouTube -->
#        <a class="b-outpost-icon" href="https://www.youtube.com/user/CalUofPA">
#         <svg version="1.1" viewbox="0 0 110 110" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#          <g fill="none" fill-rule="evenodd">
#           <g fill="#fff" transform="translate(-200 -175)">
#            <path d="m200.07 230.16c0-30.29 24.55-54.84 54.83-54.84 30.29 0 54.84 24.55 54.84 54.84 0 30.28-24.55 54.83-54.84 54.83-30.28 0-54.83-24.55-54.83-54.83zm48.28 11.08v-24.68l18.72 12.34-18.72 12.34zm39.33-24.23c0-5.41-4.38-9.8-9.8-9.8h-45.95c-5.42 0-9.8 4.39-9.8 9.8v26.29c0 5.41 4.38 9.8 9.8 9.8h45.95c5.42 0 9.8-4.39 9.8-9.8v-26.29z" id="icon-youtube">
#            </path>
#           </g>
#          </g>
#         </svg>
#         <span class="calu-hidden">
#          Watch us on YouTube
#         </span>
#        </a>
#        <!-- Twitter -->
#        <a class="b-outpost-icon" href="https://www.twitter.com/CalUofPA">
#         <svg version="1.1" viewbox="0 0 110 111" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#          <g fill="none" fill-rule="evenodd">
#           <g fill="#fff" transform="translate(-340 -175)">
#            <path d="m340.14 230.74c0-30.28 24.55-54.83 54.84-54.83 30.28 0 54.83 24.55 54.83 54.83s-24.55 54.83-54.83 54.83c-30.29 0-54.84-24.55-54.84-54.83zm88.68-20.99c-2.49 1.1-5.17 1.85-7.98 2.18 2.87-1.72 5.07-4.44 6.11-7.68-2.68 1.59-5.66 2.75-8.82 3.37-2.53-2.7-6.14-4.39-10.14-4.39-7.67 0-13.88 6.22-13.88 13.89 0 1.09 0.12 2.15 0.36 3.17-11.54-0.58-21.78-6.11-28.63-14.51-1.19 2.05-1.88 4.43-1.88 6.98 0 4.81 2.46 9.07 6.18 11.56-2.27-0.08-4.42-0.7-6.29-1.74v0.17c0 6.73 4.79 12.34 11.14 13.62-1.16 0.32-2.39 0.49-3.66 0.49-0.89 0-1.76-0.09-2.61-0.25 1.77 5.51 6.89 9.53 12.97 9.64-4.75 3.73-10.74 5.95-17.25 5.95-1.12 0-2.22-0.07-3.31-0.2 6.15 3.94 13.45 6.24 21.29 6.24 25.54 0 39.51-21.16 39.51-39.51 0-0.6-0.01-1.2-0.04-1.8 2.71-1.95 5.07-4.4 6.93-7.18z" id="icon-twitter">
#            </path>
#           </g>
#          </g>
#         </svg>
#         <span class="calu-hidden">
#          Follow us on Twitter
#         </span>
#        </a>
#        <!-- LinkedIn -->
#        <a class="b-outpost-icon" href="https://www.linkedin.com/school/35882/">
#         <svg version="1.1" viewbox="0 0 110 110" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#          <g fill="none" fill-rule="evenodd">
#           <g fill="#fff" transform="translate(-200 -37)">
#            <path d="m200.07 91.833c0-30.284 24.55-54.833 54.83-54.833 30.29 0 54.84 24.549 54.84 54.833 0 30.287-24.55 54.837-54.84 54.837-30.28 0-54.83-24.55-54.83-54.837zm28.07 26.197h12.66v-38.053h-12.66v38.053zm6.41-56.397c-4.33 0-7.16 2.841-7.16 6.574 0 3.654 2.75 6.577 7 6.577h0.08c4.41 0 7.16-2.923 7.16-6.577-0.09-3.733-2.75-6.574-7.08-6.574zm51.87 34.576c0-11.687-6.25-17.125-14.57-17.125-6.72 0-9.72 3.698-11.41 6.286v0.125h-0.08l0.08-0.125v-5.393h-12.65c0.17 3.571 0 38.053 0 38.053h12.65v-21.251c0-1.141 0.09-2.271 0.42-3.084 0.92-2.276 3-4.627 6.49-4.627 4.59 0 6.41 3.491 6.41 8.605v20.357h12.66v-21.821z" id="icon-linkedin">
#            </path>
#           </g>
#          </g>
#         </svg>
#         <span class="calu-hidden">
#          Join us on LinkedIn
#         </span>
#        </a>
#        <!-- Instagram -->
#        <a class="b-outpost-icon" href="https://www.instagram.com/caluofpa/">
#         <svg version="1.1" viewbox="0 0 110 111" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#          <g fill="none" fill-rule="evenodd">
#           <g fill="#fff" transform="translate(-60 -313)">
#            <path d="m60 368.48c0-30.29 24.549-54.84 54.83-54.84 30.29 0 54.83 24.55 54.83 54.84 0 30.28-24.54 54.83-54.83 54.83-30.281 0-54.83-24.55-54.83-54.83zm77.06-15.28c0 0.82-0.56 1.38-1.38 1.38h-5.57c-0.83 0-1.38-0.56-1.38-1.38v-5.57c0-0.82 0.55-1.38 1.38-1.38h5.57c0.82 0 1.38 0.56 1.38 1.38v5.57zm-43.071 37.5c-0.828 0-1.384-0.55-1.384-1.38v-23.62h5.837c-0.287 0.84-0.287 1.95-0.287 2.78 0 9.17 7.505 16.67 16.675 16.67s16.68-7.5 16.68-16.67c0-0.83 0-1.94-0.29-2.78h5.84v23.62c0 0.83-0.56 1.38-1.38 1.38h-41.691zm20.841-33.34c6.12 0 11.12 5 11.12 11.12s-5 11.11-11.12 11.11-11.11-4.99-11.11-11.11 4.99-11.12 11.11-11.12zm22.23-16.67h-44.455c-3.066 0-5.563 2.49-5.563 5.56v44.45c0 3.07 2.497 5.57 5.563 5.57h44.455c3.07 0 5.56-2.5 5.56-5.57v-44.45c0-3.07-2.49-5.56-5.56-5.56z" id="icon-instagram">
#            </path>
#           </g>
#          </g>
#         </svg>
#         <span class="calu-hidden">
#          Follow us on Instagram
#         </span>
#        </a>
#       </div>
#       <ul class="b-footer-band__links b-list-reset">
#        <li>
#         <a href="https://careers.calu.edu/applicants/jsp/shared/Welcome_css.jsp">
#          Employment
#         </a>
#        </li>
#        <li>
#         <a href="https://www.calu.edu/contact-us.aspx">
#          Contact Us
#         </a>
#        </li>
#        <li>
#         <a href="https://www.calu.edu/people-finder/">
#          People Finder
#         </a>
#        </li>
#        <li>
#         <a href="https://www.calu.edu/news/">
#          News &amp; Media
#         </a>
#        </li>
#        <li>
#         <a href="https://www.calu.edu/calendar/index.php">
#          Events &amp; Calendar
#         </a>
#        </li>
#        <li>
#         <a href="https://calvulcans.com/">
#          Athletics
#         </a>
#        </li>
#        <li>
#         <a href="https://www.calu.edu/inside/campus-safety/">
#          Emergency Information
#         </a>
#        </li>
#        <li>
#         <a href="https://secure.ethicspoint.com/domain/media/en/gui/37117/index.html">
#          Fraud/Waste/Abuse
#         </a>
#        </li>
#        <li>
#         <a href="https://www.bkstr.com/californiau-pennstore/home/en?cm_mmc=Redirect-_-VanityURL-_-calupa.bkstr.com-_-10422">
#          Bookstore
#         </a>
#        </li>
#        <li>
#         <a href="https://www.calu.edu/convocation-center/index.html">
#          Convocation Center
#         </a>
#        </li>
#        <li>
#         <a href="https://www.calu.edu/inside/titleix.aspx">
#          Title IX
#         </a>
#        </li>
#        <li>
#         <a href="https://www.calu.edu/alumni/">
#          Alumni Relations
#         </a>
#        </li>
#       </ul>
#      </div>
#      <div class="b-footer-band__column b-footer-band__column--one">
#       <a class="b-footer-band__logo" href="/" style="display: block;">
#        <span class="calu-hidden">
#         California Univeristy of Pennsylvania homepage
#        </span>
#        <img alt="Footer Logo" src="/_resources/images/tower-logo-compressor.svg">
#        </img>
#       </a>
#       <span class="b-footer-band__text">
#        California University of Pennsylvania, 250 University Ave., California, PA 15419
#       </span>
#       <span class="b-footer-band__text">
#        <a class="b-footer-band__icon-link b-footer-band__icon-link--tel" href="tel:1-724-938-4000">
#         724-938-4000
#        </a>
#        <a class="b-footer-band__icon-link b-footer-band__icon-link--map" href="/calu-difference/campus/directions.aspx">
#         Maps &amp; Directions
#        </a>
#       </span>
#       <a class="b-vip-logo" href="https://vip.calu.edu/">
#        <img alt="Cal U Vulcan Information Portal" src="/_resources/images/vip-logo.png">
#        </img>
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="b-footer-band b-footer-band--black b-footer-band--last" role="contentinfo">
#     <div class="b-footer-band__text">
#      <span style="margin-right: 3rem">
#       <span id="directedit">
#        ©
#       </span>
#       Copyright 2017 California University of Pennsylvania
#      </span>
#      <a class="b-footer-band__link" href="https://www.calu.edu/inside/disclaimer.aspx">
#       Disclaimer
#      </a>
#      <a class="b-footer-band__link" href="https://www.calu.edu/inside/right-to-know.aspx">
#       RIGHT TO KNOW
#      </a>
#     </div>
#     <a class="b-pashhe-logo" href="http://www.passhe.edu/">
#      <img alt="PASHHE" src="/_resources/images/icon-passhe-compressor.svg">
#      </img>
#     </a>
#    </div>
#   </footer>
#   <script src="/_resources/js/all.js">
#   </script>
#   <script src="/_resources/js/ou.js">
#   </script>
#   <script src="/_resources/js/direct-edit.js">
#   </script>
#   <!-- Insert google analytics here -->
#   <div id="hidden" style="display:none;">
#    <a href="http://ou.calu.edu/10?skin=oucampus&amp;account=calu&amp;site=www&amp;action=de&amp;path=/academics/undergraduate/bachelors/data-science/what-can-you-do-with-a-statistics-and-data-science-degree.pcf" id="de">
#     Ⓒ
#    </a>
#   </div>
#  </body>
# </html>

# %%
#quotes = soup.find_all(id="main-content")
quotes = title_soup.find_all('ul')[6:7]
for quote in quotes:
    job_dict = dict()
    job_list = []
    
    try:
        for strong_tag in quote.find_all('strong'):
            if (strong_tag.text.find(':') != -1):
                strong_text = strong_tag.text.split(":")[0]
            elif (strong_tag.text.find('$') != -1):
                salary = strong_tag.text
                 #print(strong_text)
                job_dict = {"job_title": strong_text, "salary": salary}
                job_list.append(job_dict)
    except:
        print("out of range")
        
job_title_df = pd.DataFrame(job_list)
job_title_df
# Out:
#                         job_title     salary
# 0                  Data scientist   $120,931
# 1   Business intelligence analyst   $79,613
# 2       Chief information officer  $121,652
# 3          Data warehouse analyst   $71,328
# 4    Data Visualization Developer  $118,500
# 5         Business System Analyst   $74,668
# 6             Data mining analyst    $65,470
# 7    Big Data Solutions Architect  $116,171
# 8                Database manager   $76,088
# 9                    Data modeler   $78,601
# 10             Database developer   $86,090
# 11         Database administrator   $77,428
# 12                Data strategist  $57, 946
# 13          Business data analyst   $67,610
# 14                  Data engineer   $137,776
# 15      Machine learning engineer  $120,931

# %%
# copy the output to a csv file
job_title_df.to_csv('output/job_title.csv', index = False)

# %%
from config import username, password
print(username)
print(password)

from sqlalchemy import create_engine
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/etl_db')
conn = engine.connect()
# Out:
# postgres
# postgres123

# %%
#cur = conn.cursor()
engine.execute("""delete from job_info""")
engine.execute("""INSERT INTO job_info(job_title,salary) VALUES (%(job_title)s, %(salary)s)""", job_list)

# %% [markdown]
# ## Source: https://www.indeed.com/salaries

# %%
# use the job titles to search through indeed.com to get the salary info
executable_path = {'executable_path': 'chromedriver.exe'}
print(executable_path)
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# {'executable_path': 'chromedriver.exe'}

# %%
url = 'https://www.indeed.com/salaries'
browser.visit(url)
time.sleep(1)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')
#print(soup.prettify())

# %%
job_titles = ["data entry clerk", "entry level data analyst",'junior data analyst', 
              'data analyst', 'senior data analyst', 
              'data engineer', 'data scientist', 'senior data scientist', 'lead data scientist'
              'principal data scientist','business analyst','Business intelligence analyst',
              'Business intelligence developer', 'software engineer', 'Senior Software Engineer',
              "Chief information officer", "Business Systems Analyst",
             "Data Warehouse Architect", "Software Architect",
             "Database manager","Senior Data modeler", "Database developer", 
              "Database administrator", "Machine learning engineer", "tableau developer"]
#job_titles = ["data entry clerk", "entry level data analyst"]

# Test Case - try specific title
#job_titles = ['principal data scientist']

salaries_by_job_title = []
salary_type_by_job_title = []
salary_description = []
source_urls = []
number_of_salaries_reported = []

# %%
for job in job_titles:
    avg_salary = 'NaN'
    avg_salary_type = 'NaN'
    avg_salary_summary = 'NaN'
    number_of_salaries = 'NaN'
    try:
        print(f'START: Searching for job title: {job}')
        try:
            print('----Trying to find SEARCH BOX by class type 1--------')
            browser.find_by_id('cmp-salary-search-input').first.fill(job)
        except:
            try:
                print('----Trying to find SEARCH BOX by class type 2--------')
                browser.find_by_id('cmp-salary-search-input-title').first.fill(job)
            except:
                print('----ERROR: Could find search box by either class--------')

        time.sleep(1)
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
#         print(soup.prettify())
        
        search_results = soup.find('div', class_='cmp-salary-search-results')
#         print(search_results)

        keywords = search_results.find_all('a', class_='cmp-salary-search-result-title')
        for keyword in keywords:
            print(f'SEARCH BOX Keyword returned: {keyword.text}')
        
        # When search field is filled, it dynamically loads a list of job titles in drop-down list. 
        # We ignore choices by doing a partial text search on title we are looking for and if no
        # match exists, find the last link "popular salaries for <title>" and mouse over, so webpage
        # changes the class to forice it in search.
        
        option = browser.links.find_by_partial_text(job)
        option.mouse_over()
        print(f'Mouse Over completed for option: {option.text}')
        browser.click_link_by_id('cmp-salary-search-submit')
        time.sleep(1)
        print(browser.url)
        browser.visit(browser.url)
        time.sleep(1)
        html = browser.html
        soup = BeautifulSoup(html, 'html.parser')
        #print(soup.prettify())
        try:
            print('-----Trying Results Page type 1-------')
            avg_salary = soup.find('div', class_='sal-agg-nonbase__average-salary-value').text
            avg_salary_type = soup.find('div', class_='sal-agg-nonbase__average-salary-type').text   
            avg_salary_summary = soup.find('h3', class_='sal-agg-nonbase__salary-explain-summary').text
            salaries_by_job_title.append(avg_salary)
            salary_type_by_job_title.append(avg_salary_type)
            salary_description.append(avg_salary_summary)
            source_urls.append(browser.url)
            salaries_reported_string = soup.find('div', class_='sal-agg-nonbase__salary-reported').text
            salaries_reported = salaries_reported_string.split('salaries reported')
            print(salaries_reported)
            number_of_salaries = salaries_reported[0]
            number_of_salaries_reported.append(number_of_salaries)
            print('-----Completed Results Page type 1-------')
        except:
            try:
                print('----- Trying Results Page type 2-------')
                avg_salary = soup.find('strong', class_='cmp-salary-amount').text           
                avg_salary_type = soup.find('div', class_='cmp-sal-salary').text 
                avg_salary_type_array = avg_salary_type.split('per') 
                avg_salary_type = f'per{avg_salary_type_array[1]}'
                avg_salary_summary = soup.find('div', class_='cmp-salary-blurb-text').text  
                salaries_by_job_title.append(avg_salary)
                salary_type_by_job_title.append(avg_salary_type)
                salary_description.append(avg_salary_summary)
                source_urls.append(browser.url)
                salaries_reported_string = soup.find('div', class_='cmp-salary-header-content').text
                salaries_reported = salaries_reported_string.split('Salary estimated from')
                print(salaries_reported)
                number_of_salaries = salaries_reported[1].split(' ')
                number_of_salaries = number_of_salaries[1]
                number_of_salaries_reported.append(number_of_salaries)
                print('----- Completed Results Page type 2-------')
            except:
                print('----- No Salary results found -------')
                avg_salary = 'NaN'
                salaries_by_job_title.append(avg_salary)
                salary_type_by_job_title.append(avg_salary_type)
                salary_description.append(avg_salary_summary)
                source_urls.append(browser.url)    
                number_of_salaries_reported.append(number_of_salaries)
            
        print('RECORD elements inserted in lists')
        print('---------------------------------')
        print(avg_salary)
        print(avg_salary_type)
        print(avg_salary_summary)
        print(number_of_salaries)
        browser.back()
        time.sleep(1)
    except AttributeError as e:
        print(f'ERROR: {e}')
# Out:
# START: Searching for job title: data entry clerk
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Data Entry Clerk
# Mouse Over completed for option: Popular salaries for data entry clerk
# https://www.indeed.com/career/data-entry-clerk/salaries
# -----Trying Results Page type 1-------
# ['21.7k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $2,246
# per month
# The average salary for a data entry clerk  is $2,246 per month in the United States.
# 21.7k
# START: Searching for job title: entry level data analyst
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Entry Level Data Analyst
# Mouse Over completed for option: Popular salaries for entry level data analyst
# https://www.indeed.com/salaries/entry%20level%20data%20analyst
# -----Trying Results Page type 1-------
# ----- Trying Results Page type 2-------
# ['', ' 190 employees, users, and past and present job advertisements on Indeed in the past 36 months.\xa0Last updated: August 17, 2020']
# ----- Completed Results Page type 2-------
# RECORD elements inserted in lists
# ---------------------------------
# $60,030
# per year
# The average salary for an  Entry Level Data Analyst is $60,030 per year in the United States. Salary estimates are based on 190 salaries submitted anonymously to Indeed by Entry Level Data Analyst employees, users, and collected from past and present job advertisements on Indeed in the past 36 months.
# 190
# START: Searching for job title: junior data analyst
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Junior Data Analyst
# Mouse Over completed for option: Popular salaries for junior data analyst
# https://www.indeed.com/career/junior-data-analyst/salaries
# -----Trying Results Page type 1-------
# ['160 ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $57,186
# per year
# The average salary for a junior data analyst  is $57,186 per year in the United States.
# 160
# START: Searching for job title: data analyst
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Data Entry Clerk
# SEARCH BOX Keyword returned: Data Analyst
# SEARCH BOX Keyword returned: Senior Data Analyst
# SEARCH BOX Keyword returned: Data Analyst Manager
# SEARCH BOX Keyword returned: Junior Data Analyst
# SEARCH BOX Keyword returned: Entry Level Data Analyst
# Mouse Over completed for option: Popular salaries for data analyst
# https://www.indeed.com/career/data-analyst/salaries
# -----Trying Results Page type 1-------
# ['6k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $75,087
# per year
# The average salary for a data analyst  is $75,087 per year in the United States and  $2,500 cash bonus per year.
# 6k
# START: Searching for job title: senior data analyst
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Senior Data Analyst
# Mouse Over completed for option: Popular salaries for senior data analyst
# https://www.indeed.com/career/senior-data-analyst/salaries
# -----Trying Results Page type 1-------
# ['1.6k ', ', updated at Aug 29, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $96,154
# per year
# The average salary for a senior data analyst  is $96,154 per year in the United States and  $3,650 cash bonus per year.
# 1.6k
# START: Searching for job title: data engineer
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Data Engineer
# SEARCH BOX Keyword returned: Data Warehouse Engineer
# Mouse Over completed for option: Popular salaries for data engineer
# https://www.indeed.com/career/data-engineer/salaries
# -----Trying Results Page type 1-------
# ['7.8k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $129,402
# per year
# The average salary for a data engineer  is $129,402 per year in the United States and  $5,000 cash bonus per year.
# 7.8k
# START: Searching for job title: data scientist
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Data Scientist
# SEARCH BOX Keyword returned: Senior Data Scientist
# SEARCH BOX Keyword returned: Lead Data Scientist
# SEARCH BOX Keyword returned: Junior Data Scientist
# Mouse Over completed for option: Popular salaries for data scientist
# https://www.indeed.com/career/data-scientist/salaries
# -----Trying Results Page type 1-------
# ['5.2k ', ', updated at Aug 30, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $121,625
# per year
# The average salary for a data scientist  is $121,625 per year in the United States.
# 5.2k
# START: Searching for job title: senior data scientist
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Senior Data Scientist
# Mouse Over completed for option: Popular salaries for senior data scientist
# https://www.indeed.com/career/senior-data-scientist/salaries
# -----Trying Results Page type 1-------
# ['1.5k ', ', updated at Aug 29, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $151,027
# per year
# The average salary for a senior data scientist  is $151,027 per year in the United States.
# 1.5k
# START: Searching for job title: lead data scientistprincipal data scientist
# ----Trying to find SEARCH BOX by class type 1--------
# Mouse Over completed for option: Popular salaries for lead data scientistprincipal data scientist
# https://www.indeed.com/salaries/lead%20data%20scientistprincipal%20data%20scientist
# -----Trying Results Page type 1-------
# ----- Trying Results Page type 2-------
# ----- No Salary results found -------
# RECORD elements inserted in lists
# ---------------------------------
# NaN
# per year
# NaN
# NaN
# START: Searching for job title: business analyst
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Business Analyst
# SEARCH BOX Keyword returned: Business Systems Analyst
# SEARCH BOX Keyword returned: Senior Business Analyst
# SEARCH BOX Keyword returned: Business Intelligence Analyst
# SEARCH BOX Keyword returned: Business Process Analyst
# SEARCH BOX Keyword returned: Project Manager/Business Analyst
# SEARCH BOX Keyword returned: Business Development Analyst
# SEARCH BOX Keyword returned: Senior Business Intelligence Analyst
# SEARCH BOX Keyword returned: Senior Business Process Analyst
# Mouse Over completed for option: Popular salaries for business analyst
# https://www.indeed.com/career/business-analyst/salaries
# -----Trying Results Page type 1-------
# ['7.8k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $80,034
# per year
# The average salary for a business analyst  is $80,034 per year in the United States and  $4,000 cash bonus per year.
# 7.8k
# START: Searching for job title: Business intelligence analyst
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Business Intelligence Analyst
# SEARCH BOX Keyword returned: Senior Business Intelligence Analyst
# SEARCH BOX Keyword returned: Business Intelligence Analyst Intern
# SEARCH BOX Keyword returned: Junior Business Intelligence Analyst
# Mouse Over completed for option: Popular salaries for Business intelligence analyst
# https://www.indeed.com/career/business-intelligence-analyst/salaries
# -----Trying Results Page type 1-------
# ['1.6k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $95,829
# per year
# The average salary for a business intelligence analyst  is $95,829 per year in the United States and  $5,000 cash bonus per year.
# 1.6k
# START: Searching for job title: Business intelligence developer
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Business Intelligence Developer
# Mouse Over completed for option: Popular salaries for Business intelligence developer
# https://www.indeed.com/career/business-intelligence-developer/salaries
# -----Trying Results Page type 1-------
# ['1.7k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $102,221
# per year
# The average salary for a business intelligence developer  is $102,221 per year in the United States and  $5,000 cash bonus per year.
# 1.7k
# START: Searching for job title: software engineer
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Software Engineer
# SEARCH BOX Keyword returned: Senior Software Engineer
# SEARCH BOX Keyword returned: Software Test Engineer
# Mouse Over completed for option: Popular salaries for software engineer
# https://www.indeed.com/career/software-engineer/salaries
# -----Trying Results Page type 1-------
# ['37.6k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $110,124
# per year
# The average salary for a software engineer  is $110,124 per year in the United States and  $4,000 cash bonus per year.
# 37.6k
# START: Searching for job title: Senior Software Engineer
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Senior Software Engineer
# SEARCH BOX Keyword returned: Senior Software Test Engineer
# Mouse Over completed for option: Senior Software Engineer
# https://www.indeed.com/career/senior-software-engineer/salaries
# -----Trying Results Page type 1-------
# ['26.7k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $132,408
# per year
# The average salary for a senior software engineer  is $132,408 per year in the United States and  $5,000 cash bonus per year.
# 26.7k
# START: Searching for job title: Chief information officer
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Chief Information Officer
# Mouse Over completed for option: Popular salaries for Chief information officer
# https://www.indeed.com/career/chief-information-officer/salaries
# -----Trying Results Page type 1-------
# ['453 ', ', updated at Aug 28, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $129,933
# per year
# The average salary for a chief information officer  is $129,933 per year in the United States and  $21,200 profit sharing per year.
# 453
# START: Searching for job title: Business Systems Analyst
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Business Systems Analyst
# Mouse Over completed for option: Business Systems Analyst
# https://www.indeed.com/career/business-systems-analyst/salaries
# -----Trying Results Page type 1-------
# ['3.5k ', ', updated at Aug 30, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $90,481
# per year
# The average salary for a business systems analyst  is $90,481 per year in the United States and  $5,000 cash bonus per year.
# 3.5k
# START: Searching for job title: Data Warehouse Architect
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Data Warehouse Architect
# Mouse Over completed for option: Data Warehouse Architect
# https://www.indeed.com/salaries/data-warehouse-architect-Salaries
# -----Trying Results Page type 1-------
# ----- Trying Results Page type 2-------
# ['', ' 743 employees, users, and past and present job advertisements on Indeed in the past 36 months.\xa0Last updated: August 28, 2020']
# ----- Completed Results Page type 2-------
# RECORD elements inserted in lists
# ---------------------------------
# $134,367
# per year
# The average salary for a  Data Warehouse Architect is $134,367 per year in the United States. Salary estimates are based on 743 salaries submitted anonymously to Indeed by Data Warehouse Architect employees, users, and collected from past and present job advertisements on Indeed in the past 36 months. The typical tenure for a  Data Warehouse Architect is less than 1 year.
# 743
# START: Searching for job title: Software Architect
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Software Architect
# SEARCH BOX Keyword returned: Senior Software Architect
# Mouse Over completed for option: Software Architect
# https://www.indeed.com/career/software-architect/salaries
# -----Trying Results Page type 1-------
# ['12.9k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $138,735
# per year
# The average salary for a software architect  is $138,735 per year in the United States and  $10,000 cash bonus per year.
# 12.9k
# START: Searching for job title: Database manager
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Database Manager
# Mouse Over completed for option: Popular salaries for Database manager
# https://www.indeed.com/salaries/database-manager-Salaries
# -----Trying Results Page type 1-------
# ----- Trying Results Page type 2-------
# ['', ' 234 employees, users, and past and present job advertisements on Indeed in the past 36 months.\xa0Last updated: August 26, 2020']
# ----- Completed Results Page type 2-------
# RECORD elements inserted in lists
# ---------------------------------
# $64,908
# per year
# The average salary for a  Database Manager is $64,908 per year in the United States. Salary estimates are based on 234 salaries submitted anonymously to Indeed by Database Manager employees, users, and collected from past and present job advertisements on Indeed in the past 36 months. The typical tenure for a  Database Manager is 1-3 years.
# 234
# START: Searching for job title: Senior Data modeler
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Senior Data Modeler
# Mouse Over completed for option: Popular salaries for Senior Data modeler
# https://www.indeed.com/salaries/senior-data-modeler-Salaries
# -----Trying Results Page type 1-------
# ----- Trying Results Page type 2-------
# ['', ' 62 employees, users, and past and present job advertisements on Indeed in the past 36 months.\xa0Last updated: August 13, 2020']
# ----- Completed Results Page type 2-------
# RECORD elements inserted in lists
# ---------------------------------
# $106,303
# per year
# The average salary for a  Senior Data Modeler is $106,303 per year in the United States. Salary estimates are based on 62 salaries submitted anonymously to Indeed by Senior Data Modeler employees, users, and collected from past and present job advertisements on Indeed in the past 36 months. The typical tenure for a  Senior Data Modeler is less than 1 year.
# 62
# START: Searching for job title: Database developer
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Database Developer
# SEARCH BOX Keyword returned: Senior Database Developer
# SEARCH BOX Keyword returned: Junior Database Developer
# Mouse Over completed for option: Popular salaries for Database developer
# https://www.indeed.com/career/database-developer/salaries
# -----Trying Results Page type 1-------
# ['454 ', ', updated at Aug 28, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $89,521
# per year
# The average salary for a database developer  is $89,521 per year in the United States and  $2,800 cash bonus per year.
# 454
# START: Searching for job title: Database administrator
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Database Administrator
# SEARCH BOX Keyword returned: Senior Database Administrator
# SEARCH BOX Keyword returned: Junior Database Administrator
# Mouse Over completed for option: Popular salaries for Database administrator
# https://www.indeed.com/career/database-administrator/salaries
# -----Trying Results Page type 1-------
# ['2.5k ', ', updated at Aug 31, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $98,157
# per year
# The average salary for a database administrator  is $98,157 per year in the United States.
# 2.5k
# START: Searching for job title: Machine learning engineer
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Machine Learning Engineer
# Mouse Over completed for option: Popular salaries for Machine learning engineer
# https://www.indeed.com/career/machine-learning-engineer/salaries
# -----Trying Results Page type 1-------
# ['1.6k ', ', updated at Aug 29, 2020']
# -----Completed Results Page type 1-------
# RECORD elements inserted in lists
# ---------------------------------
# $144,300
# per year
# The average salary for a machine learning engineer  is $144,300 per year in the United States.
# 1.6k
# START: Searching for job title: tableau developer
# ----Trying to find SEARCH BOX by class type 1--------
# SEARCH BOX Keyword returned: Tableau Developer
# Mouse Over completed for option: Popular salaries for tableau developer
# https://www.indeed.com/salaries/tableau%20developer
# -----Trying Results Page type 1-------
# ----- Trying Results Page type 2-------
# ['', ' 339 employees, users, and past and present job advertisements on Indeed in the past 36 months.\xa0Last updated: August 28, 2020']
# ----- Completed Results Page type 2-------
# RECORD elements inserted in lists
# ---------------------------------
# $56.38
# per hour
# The average salary for a  Tableau Developer is $56.38 per hour in the United States. Salary estimates are based on 339 salaries submitted anonymously to Indeed by Tableau Developer employees, users, and collected from past and present job advertisements on Indeed in the past 36 months.
# 339

# %%
browser.quit()

# %%
print(len(job_titles), len(salaries_by_job_title), len(salary_type_by_job_title), len(salary_description), 
      len(source_urls))
# Out:
# 24 24 24 24 24

# %%
salary_table = pd.DataFrame({"Job Title":job_titles,
                             "Avg Salary":salaries_by_job_title,
                             "Salary Type": salary_type_by_job_title,
                             "Number of Salaries Reported": number_of_salaries_reported,
                             "Salary Description": salary_description,
                             "Source URL": source_urls,
                             })
salary_table
# Out:
#                                       Job Title Avg Salary Salary Type  \
# 0                              data entry clerk     $2,246   per month
# 1                      entry level data analyst    $60,030    per year
# 2                           junior data analyst    $57,186    per year
# 3                                  data analyst    $75,087    per year
# 4                           senior data analyst    $96,154    per year
# 5                                 data engineer   $129,402    per year
# 6                                data scientist   $121,625    per year
# 7                         senior data scientist   $151,027    per year
# 8   lead data scientistprincipal data scientist        NaN    per year
# 9                              business analyst    $80,034    per year
# 10                Business intelligence analyst    $95,829    per year
# 11              Business intelligence developer   $102,221    per year
# 12                            software engineer   $110,124    per year
# 13                     Senior Software Engineer   $132,408    per year
# 14                    Chief information officer   $129,933    per year
# 15                     Business Systems Analyst    $90,481    per year
# 16                     Data Warehouse Architect   $134,367    per year
# 17                           Software Architect   $138,735    per year
# 18                             Database manager    $64,908    per year
# 19                          Senior Data modeler   $106,303    per year
# 20                           Database developer    $89,521    per year
# 21                       Database administrator    $98,157    per year
# 22                    Machine learning engineer   $144,300    per year
# 23                            tableau developer     $56.38    per hour
#
#    Number of Salaries Reported  \
# 0                       21.7k
# 1                          190
# 2                         160
# 3                          6k
# 4                        1.6k
# 5                        7.8k
# 6                        5.2k
# 7                        1.5k
# 8                          NaN
# 9                        7.8k
# 10                       1.6k
# 11                       1.7k
# 12                      37.6k
# 13                      26.7k
# 14                        453
# 15                       3.5k
# 16                         743
# 17                      12.9k
# 18                         234
# 19                          62
# 20                        454
# 21                       2.5k
# 22                       1.6k
# 23                         339
#
#                                    Salary Description  \
# 0   The average salary for a data entry clerk  is ...
# 1   The average salary for an  Entry Level Data An...
# 2   The average salary for a junior data analyst  ...
# 3   The average salary for a data analyst  is $75,...
# 4   The average salary for a senior data analyst  ...
# 5   The average salary for a data engineer  is $12...
# 6   The average salary for a data scientist  is $1...
# 7   The average salary for a senior data scientist...
# 8                                                 NaN
# 9   The average salary for a business analyst  is ...
# 10  The average salary for a business intelligence...
# 11  The average salary for a business intelligence...
# 12  The average salary for a software engineer  is...
# 13  The average salary for a senior software engin...
# 14  The average salary for a chief information off...
# 15  The average salary for a business systems anal...
# 16  The average salary for a  Data Warehouse Archi...
# 17  The average salary for a software architect  i...
# 18  The average salary for a  Database Manager is ...
# 19  The average salary for a  Senior Data Modeler ...
# 20  The average salary for a database developer  i...
# 21  The average salary for a database administrato...
# 22  The average salary for a machine learning engi...
# 23  The average salary for a  Tableau Developer is...
#
#                                            Source URL
# 0   https://www.indeed.com/career/data-entry-clerk...
# 1   https://www.indeed.com/salaries/entry%20level%...
# 2   https://www.indeed.com/career/junior-data-anal...
# 3   https://www.indeed.com/career/data-analyst/sal...
# 4   https://www.indeed.com/career/senior-data-anal...
# 5   https://www.indeed.com/career/data-engineer/sa...
# 6   https://www.indeed.com/career/data-scientist/s...
# 7   https://www.indeed.com/career/senior-data-scie...
# 8   https://www.indeed.com/salaries/lead%20data%20...
# 9   https://www.indeed.com/career/business-analyst...
# 10  https://www.indeed.com/career/business-intelli...
# 11  https://www.indeed.com/career/business-intelli...
# 12  https://www.indeed.com/career/software-enginee...
# 13  https://www.indeed.com/career/senior-software-...
# 14  https://www.indeed.com/career/chief-informatio...
# 15  https://www.indeed.com/career/business-systems...
# 16  https://www.indeed.com/salaries/data-warehouse...
# 17  https://www.indeed.com/career/software-archite...
# 18  https://www.indeed.com/salaries/database-manag...
# 19  https://www.indeed.com/salaries/senior-data-mo...
# 20  https://www.indeed.com/career/database-develop...
# 21  https://www.indeed.com/career/database-adminis...
# 22  https://www.indeed.com/career/machine-learning...
# 23  https://www.indeed.com/salaries/tableau%20deve...

# %%
salary_table.to_csv(r'output/avg_salary_by_title.csv', index = False)

# %%
engine.execute("""drop table salary_info""")

# write to the DB
salary_table = salary_table.replace(np.nan, '', regex=True)
salary_table.to_sql('salary_info', con=engine, index=False)

# %% [markdown]
# ## Source: https://www.kaggle.com

# %%
#Read Data Analyst CSV file 
csv_file = 'Resources/DataAnalyst.csv'
data_analyst_df = pd.read_csv(csv_file)
data_analyst_df.head()

#Clean Data Analyst DataFrame
new_data_analyst_df = data_analyst_df[['Job Title', 'Salary Estimate', 'Industry', 'Location']].copy()
new_data_analyst_df.dropna()
new_data_analyst_df.head()
# Out:
#                                            Job Title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               Salary Estimate                          Industry      Location
# 0  $37K-$66K (Glassdoor est.)                 Social Assistance  New York, NY
# 1  $37K-$66K (Glassdoor est.)  Health Care Services & Hospitals  New York, NY
# 2  $37K-$66K (Glassdoor est.)                          Internet  New York, NY
# 3  $37K-$66K (Glassdoor est.)                       IT Services  New York, NY
# 4  $37K-$66K (Glassdoor est.)               Sports & Recreation  New York, NY

# %%
clean_salary_estimate = new_data_analyst_df['Salary Estimate'].head()
clean_salary_estimate
new_data_analyst_df['Salary Estimate'].str.split('-')
new=new_data_analyst_df["Salary Estimate"].str.split(" ", n = 1, expand = True)
sal_range=new[0].str.split('-',n=1,expand=True)
new_data_analyst_df['Lower'] = sal_range[0]
new_data_analyst_df['Upper'] = sal_range[1]
#new_data_analyst_df.head()
#new_data_analyst_df.drop('Salary Estimate',axis=1,inplace=True)
#new_data_analyst_df.head()
new_data_analyst_df['Lower']=new_data_analyst_df['Lower'].str.replace('K','000')
new_data_analyst_df['Lower']=new_data_analyst_df['Lower'].str.replace('$','')
new_data_analyst_df['Upper']=new_data_analyst_df['Upper'].str.replace('K','000')
new_data_analyst_df['Upper']=new_data_analyst_df['Upper'].str.replace('P','000')
new_data_analyst_df['Upper']=new_data_analyst_df['Upper'].str.replace('$','')
new_data_analyst_df['Upper']=new_data_analyst_df['Upper'].str.rstrip("(Employer")
new_data_analyst_df.head()
clean_up = new_data_analyst_df['Upper'].unique()
new_data_analyst_df['Lower'].replace('',0,inplace=True)
new_data_analyst_df['Lower']=new_data_analyst_df['Lower'].astype('float')
new_data_analyst_df['Upper'].replace('',0,inplace=True)
new_data_analyst_df['Upper']=new_data_analyst_df['Upper'].astype('float')
#new_data_analyst_df.info()
new_data_analyst_df['Average_Sal'] = (new_data_analyst_df['Lower']+new_data_analyst_df['Upper'])/2
#new_data_analyst_df.head()

new_state = new_data_analyst_df['Location'].str.split(',',n=1,expand=True)
new_data_analyst_df['City'] = new_state[0]
new_data_analyst_df['State'] = new_state[1]

new_data_analyst_df.head()

#Rename Columns
clean_data_analyst_df = new_data_analyst_df.rename(columns={"Job Title":"job_title", "Salary Estimate":"salary_estimate", "Industry":"industry", "Location":"location","Lower":"lower","Upper":"upper","Average_Sal":"average_sal","State":"state","City":"city"})
clean_data_analyst_df.head()
# Out:
#                                            job_title  \
# 0  Data Analyst, Center on Immigration and Justic...
# 1                               Quality Data Analyst
# 2  Senior Data Analyst, Insights & Analytics Team...
# 3                                       Data Analyst
# 4                             Reporting Data Analyst
#
#               salary_estimate                          industry      location  \
# 0  $37K-$66K (Glassdoor est.)                 Social Assistance  New York, NY
# 1  $37K-$66K (Glassdoor est.)  Health Care Services & Hospitals  New York, NY
# 2  $37K-$66K (Glassdoor est.)                          Internet  New York, NY
# 3  $37K-$66K (Glassdoor est.)                       IT Services  New York, NY
# 4  $37K-$66K (Glassdoor est.)               Sports & Recreation  New York, NY
#
#      lower    upper  average_sal      city state
# 0  37000.0  66000.0      51500.0  New York    NY
# 1  37000.0  66000.0      51500.0  New York    NY
# 2  37000.0  66000.0      51500.0  New York    NY
# 3  37000.0  66000.0      51500.0  New York    NY
# 4  37000.0  66000.0      51500.0  New York    NY

# %%
#Verify tables
engine.table_names()
# Out:
# ['job_info',
#  'salary_info',
#  'data_analyst',
#  'data_analyst_final',
#  'data_scientist',
#  'data_scientist_final',
#  'data_engineer',
#  'data_engineer_final']

# %%
#Use pandas to load data analyst csv into converted DataFrame into database
clean_data_analyst_df.to_sql(name='data_analyst', con=engine, if_exists='replace', index=False)

# %%
#confirm data has been added by querying table
#psql_data_analyst = pd.read_sql_query('select * from data_analyst', con=engine)
#psql_data_analyst.head()

psql_filter_data = pd.read_sql_query("select job_title, round(cast(AVG(average_sal) as numeric),2) avgsal,state,city from data_analyst where job_title in ('Data Analyst','Senior Data Analyst','BI Data Analyst','Big Data Analyst','Data Modeler','Junior Data Analyst') group by job_title,state,city", con=engine)
psql_filter_data_df= psql_filter_data.dropna()
psql_filter_data_df.head()

#Rename Columns
report_data_analyst_df = psql_filter_data_df.rename(columns={"job_title":"job_title","avgsal":"average_sal","state":"state","city":"city"})
#report_data_analyst_df

report_data_analyst_df.to_sql(name='data_analyst_final', con=engine, if_exists='replace', index=False)

psql_final_data_analyst = pd.read_sql_query('select * from data_analyst_final', con=engine)
psql_final_data_analyst.head()
# Out:
#       job_title  average_sal state          city
# 0  Data Analyst     56000.00    VA       Norfolk
# 1  Data Analyst     61500.00    MA    Burlington
# 2  Data Analyst     66833.33    VA     Chantilly
# 3  Data Analyst     85250.00    NJ    Piscataway
# 4  Data Analyst     59281.25    PA  Philadelphia

# %%
psql_final_data_analyst.to_csv('output/DataAnalystFinal.csv')

# %%
#Read Data Scientist CSV file
csv_file = 'Resources/DataScientist.csv'
data_scienctist_df = pd.read_csv(csv_file)
data_scienctist_df.head()

#Clean Data Scientist DataFrame
new_data_scienctist_df = data_scienctist_df[['Job Title', 'Salary Estimate', 'Industry', 'Location']].copy()
new_data_scienctist_df.dropna()
new_data_scienctist_df.head()
# Out:
#                            Job Title               Salary Estimate  \
# 0              Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2               Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                       Data Analyst  $111K-$181K (Glassdoor est.)
# 4             Director, Data Science  $111K-$181K (Glassdoor est.)
#
#                     Industry       Location
# 0            Travel Agencies   New York, NY
# 1  Health, Beauty, & Fitness   New York, NY
# 2                         -1   New York, NY
# 3                   Internet  Lyndhurst, NJ
# 4    Advertising & Marketing   New York, NY

# %%
clean_salary_estimate = new_data_scienctist_df['Salary Estimate'].head()
clean_salary_estimate
new_data_scienctist_df['Salary Estimate'].str.split('-')
new=new_data_scienctist_df["Salary Estimate"].str.split(" ", n = 1, expand = True)
sal_range=new[0].str.split('-',n=1,expand=True)
new_data_scienctist_df['Lower'] = sal_range[0]
new_data_scienctist_df['Upper'] = sal_range[1]
#new_data_analyst_df.head()
#new_data_analyst_df.drop('Salary Estimate',axis=1,inplace=True)
#new_data_analyst_df.head()
new_data_scienctist_df['Lower']=new_data_scienctist_df['Lower'].str.replace('K','000')
new_data_scienctist_df['Lower']=new_data_scienctist_df['Lower'].str.replace('$','')
new_data_scienctist_df['Upper']=new_data_scienctist_df['Upper'].str.replace('K','000')
new_data_scienctist_df['Upper']=new_data_scienctist_df['Upper'].str.replace('P','000')
new_data_scienctist_df['Upper']=new_data_scienctist_df['Upper'].str.replace('$','')
new_data_scienctist_df['Upper']=new_data_scienctist_df['Upper'].str.rstrip("(Employer")
new_data_scienctist_df.head()
clean_up = new_data_scienctist_df['Upper'].unique()
new_data_scienctist_df['Lower'].replace('',0,inplace=True)
new_data_scienctist_df['Lower']=new_data_scienctist_df['Lower'].astype('float')
new_data_scienctist_df['Upper'].replace('',0,inplace=True)
new_data_scienctist_df['Upper']=new_data_scienctist_df['Upper'].astype('float')
#new_data_engineer_df.info()
new_data_scienctist_df['Average_Sal'] = (new_data_scienctist_df['Lower']+new_data_scienctist_df['Upper'])/2
#new_data_engineer_df.head()

new_state = new_data_scienctist_df['Location'].str.split(',',n=1,expand=True)
new_data_scienctist_df['City'] = new_state[0]
new_data_scienctist_df['State'] = new_state[1]

new_data_scienctist_df.head()

#Rename Columns
clean_data_scienctist_df = new_data_scienctist_df.rename(columns={"Job Title":"job_title", "Salary Estimate":"salary_estimate", "Industry":"industry", "Location":"location","Lower":"lower","Upper":"upper","Average_Sal":"average_sal","State":"state","City":"city"})
clean_data_scienctist_df.head()
# Out:
#                            job_title               salary_estimate  \
# 0              Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2               Data Science Manager  $111K-$181K (Glassdoor est.)
# 3                       Data Analyst  $111K-$181K (Glassdoor est.)
# 4             Director, Data Science  $111K-$181K (Glassdoor est.)
#
#                     industry       location     lower     upper  average_sal  \
# 0            Travel Agencies   New York, NY  111000.0  181000.0     146000.0
# 1  Health, Beauty, & Fitness   New York, NY  111000.0  181000.0     146000.0
# 2                         -1   New York, NY  111000.0  181000.0     146000.0
# 3                   Internet  Lyndhurst, NJ  111000.0  181000.0     146000.0
# 4    Advertising & Marketing   New York, NY  111000.0  181000.0     146000.0
#
#         city state
# 0   New York    NY
# 1   New York    NY
# 2   New York    NY
# 3  Lyndhurst    NJ
# 4   New York    NY

# %%
#Use pandas to load data analyst csv into converted DataFrame into database
clean_data_scienctist_df.to_sql(name='data_scientist', con=engine, if_exists='replace', index=False)

# %%
#confirm data has been added by querying table
#pd.read_sql_query('select * from data_scientist', con=engine).head()

psql_filter_data_scientist = pd.read_sql_query("select job_title, round(cast(AVG(average_sal) as numeric),2) avgsal,state,city from data_scientist where job_title in('Data Scientist','Senior Data Scientist','Junior Data Scientist','Sr Data Scientist','Data Science Technical Lead / Architect')\
                                                group by job_title,state,city", con=engine)
psql_filter_data_scientist_df= psql_filter_data_scientist.dropna()
psql_filter_data_scientist_df.head()

#Rename Columns
report_data_scientist_df = psql_filter_data_scientist_df.rename(columns={"job_title":"job_title","avgsal":"average_sal","state":"state","city":"city"})
#report_data_scientist_df

report_data_scientist_df.to_sql(name='data_scientist_final', con=engine, if_exists='replace', index=False)

psql_final_data_scientist = pd.read_sql_query('select * from data_scientist_final', con=engine)
psql_final_data_scientist.head()
# Out:
#                job_title  average_sal state          city
# 0  Senior Data Scientist    146500.00    CA       Burbank
# 1  Senior Data Scientist     85800.00    IL       Chicago
# 2         Data Scientist     61500.00    TX    Lewisville
# 3         Data Scientist    122000.00    PA  Conshohocken
# 4  Senior Data Scientist    131611.11    CA   Los Angeles

# %%
psql_final_data_scientist.to_csv('output/DataScientistFinal.csv')

# %%
#Read Data Engineer CSV file
csv_file = 'Resources/DataEngineer.csv'
data_engineer_df = pd.read_csv(csv_file)
data_engineer_df.head()

#Clean Data Engineer DataFrame
new_data_engineer_df = data_engineer_df[['Job Title', 'Salary Estimate', 'Industry', 'Location']].copy()
new_data_engineer_df.dropna()
new_data_engineer_df.head()
# Out:
#                                            Job Title  \
# 0                                      Data Engineer
# 1  Senior Data Engineer (Healthcare Domain experi...
# 2                                     Data Engineers
# 3                      Client Trade Support Engineer
# 4                                      Data Engineer
#
#                Salary Estimate                               Industry  \
# 0  $80K-$150K (Glassdoor est.)                             Consulting
# 1  $80K-$150K (Glassdoor est.)                            IT Services
# 2  $80K-$150K (Glassdoor est.)                            IT Services
# 3  $80K-$150K (Glassdoor est.)  Investment Banking & Asset Management
# 4  $80K-$150K (Glassdoor est.)                     Insurance Carriers
#
#        Location
# 0  New York, NY
# 1  New York, NY
# 2  New York, NY
# 3  New York, NY
# 4  New York, NY

# %%
clean_salary_estimate = new_data_engineer_df['Salary Estimate'].head()
clean_salary_estimate
new_data_engineer_df['Salary Estimate'].str.split('-')
new=new_data_engineer_df["Salary Estimate"].str.split(" ", n = 1, expand = True)
sal_range=new[0].str.split('-',n=1,expand=True)
new_data_engineer_df['Lower'] = sal_range[0]
new_data_engineer_df['Upper'] = sal_range[1]
#new_data_analyst_df.head()
#new_data_analyst_df.drop('Salary Estimate',axis=1,inplace=True)
#new_data_analyst_df.head()
new_data_engineer_df['Lower']=new_data_engineer_df['Lower'].str.replace('K','000')
new_data_engineer_df['Lower']=new_data_engineer_df['Lower'].str.replace('$','')
new_data_engineer_df['Upper']=new_data_engineer_df['Upper'].str.replace('K','000')
new_data_engineer_df['Upper']=new_data_engineer_df['Upper'].str.replace('P','000')
new_data_engineer_df['Upper']=new_data_engineer_df['Upper'].str.replace('$','')
new_data_engineer_df['Upper']=new_data_engineer_df['Upper'].str.rstrip("(Employer")
new_data_engineer_df.head()
clean_up = new_data_engineer_df['Upper'].unique()
new_data_engineer_df['Lower'].replace('',0,inplace=True)
new_data_engineer_df['Lower']=new_data_engineer_df['Lower'].astype('float')
new_data_engineer_df['Upper'].replace('',0,inplace=True)
new_data_engineer_df['Upper']=new_data_engineer_df['Upper'].astype('float')
#new_data_engineer_df.info()
new_data_engineer_df['Average_Sal'] = (new_data_engineer_df['Lower']+new_data_engineer_df['Upper'])/2
#new_data_engineer_df.head()

new_state = new_data_engineer_df['Location'].str.split(',',n=1,expand=True)
new_data_engineer_df['City'] = new_state[0]
new_data_engineer_df['State'] = new_state[1]

new_data_engineer_df.head()

#Rename Columns
clean_data_engineer_df = new_data_engineer_df.rename(columns={"Job Title":"job_title", "Salary Estimate":"salary_estimate", "Industry":"industry", "Location":"location","Lower":"lower","Upper":"upper","Average_Sal":"average_sal","State":"state","City":"city"})
clean_data_engineer_df.head()
# Out:
#                                            job_title  \
# 0                                      Data Engineer
# 1  Senior Data Engineer (Healthcare Domain experi...
# 2                                     Data Engineers
# 3                      Client Trade Support Engineer
# 4                                      Data Engineer
#
#                salary_estimate                               industry  \
# 0  $80K-$150K (Glassdoor est.)                             Consulting
# 1  $80K-$150K (Glassdoor est.)                            IT Services
# 2  $80K-$150K (Glassdoor est.)                            IT Services
# 3  $80K-$150K (Glassdoor est.)  Investment Banking & Asset Management
# 4  $80K-$150K (Glassdoor est.)                     Insurance Carriers
#
#        location    lower     upper  average_sal      city state
# 0  New York, NY  80000.0  150000.0     115000.0  New York    NY
# 1  New York, NY  80000.0  150000.0     115000.0  New York    NY
# 2  New York, NY  80000.0  150000.0     115000.0  New York    NY
# 3  New York, NY  80000.0  150000.0     115000.0  New York    NY
# 4  New York, NY  80000.0  150000.0     115000.0  New York    NY

# %%
engine.table_names()
# Out:
# ['job_info',
#  'salary_info',
#  'data_analyst',
#  'data_analyst_final',
#  'data_scientist',
#  'data_scientist_final',
#  'data_engineer',
#  'data_engineer_final']

# %%
#Use pandas to load data analyst csv into converted DataFrame into database
clean_data_engineer_df.to_sql(name='data_engineer', con=engine, if_exists='replace', index=False)

# %%
psql_filter_data = pd.read_sql_query("select job_title, round(cast(AVG(average_sal) as numeric),2) avgsal,state,city from data_engineer where job_title in('Data Engineer','Senior Data Engineer','Junior Data Engineer','Sr Data Engineer','Data Engineer Technical Lead','Software Engineer','Big Data Engineer','Senior Big Data Engineer','Machine Learning Engineer','Data strategist')\
                                     group by job_title,state,city", con=engine)
psql_filter_data_df= psql_filter_data.dropna()
psql_filter_data_df.head()

#Rename Columns
report_data_engineer_df = psql_filter_data_df.rename(columns={"job_title":"job_title","avgsal":"average_sal","state":"state","city":"city"})
report_data_engineer_df

report_data_engineer_df.to_sql(name='data_engineer_final', con=engine, if_exists='replace', index=False)

psql_final_data_engineer = pd.read_sql_query('select * from data_engineer_final', con=engine)
psql_final_data_engineer.head()
# Out:
#               job_title  average_sal state       city
# 0         Data Engineer     93333.33    TX      Plano
# 1         Data Engineer     88400.00    NJ     Newark
# 2     Big Data Engineer     93100.00    TX     Austin
# 3         Data Engineer    128500.00    CA  Cupertino
# 4  Senior Data Engineer     94166.67    AZ   Chandler

# %%
psql_final_data_engineer.to_csv('output/DataEngineerFinal.csv')
